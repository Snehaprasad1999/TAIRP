# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_csv('Life_Expectancy.csv')
df.head()
# Out:
#        Country  Year      Status  Adult_Mortality  Infant_Deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1      Albania  2015  Developing             74.0              0     4.60
# 2      Algeria  2015  Developing             19.0             21      NaN
# 3       Angola  2015  Developing            335.0             66      NaN
# 4      Antigua  2015  Developing             13.0              0      NaN
#
#    Hepatitis B  Measles    BMI  Underfive_Deaths   Polio  Diphtheria   HIV  \
# 0         65.0      1154  19.1                 83      6           65  0.1
# 1         99.0         0  58.0                  0     99           99  0.1
# 2         95.0        63  59.5                 24     95           95  0.1
# 3         64.0       118  23.3                 98      7           64  1.9
# 4         99.0         0  47.7                  0     86           99  0.2
#
# ...

# %%
df.shape
# Out:
# (182, 20)

# %%
df.dtypes
# Out:
# Country               object
# Year                   int64
# Status                object
# Adult_Mortality      float64
# Infant_Deaths          int64
# Alcohol              float64
# Hepatitis B          float64
# Measles                int64
# BMI                  float64
# Underfive_Deaths       int64
# Polio                  int64
# Diphtheria             int64
# HIV                  float64
# GDP                  float64
# Population           float64
# Malnourished10_19    float64
# Malnourished5_9      float64
# Income_Index         float64
# Schooling            float64
# Life_Expectancy      float64
# dtype: object

# %%
df.describe()
# Out:
#               Year  Adult_Mortality  Infant_Deaths    Alcohol  Hepatitis B  \
# count   182.000000       173.000000     182.000000  15.000000   173.000000
# mean   2014.890110       149.971098      21.741758   2.719333    81.710983
# std       0.457003        95.679846      82.297159   3.887194    25.391991
# min    2013.000000         1.000000       0.000000   0.010000     6.000000
# 25%    2015.000000        74.000000       0.000000   0.010000    78.000000
# 50%    2015.000000       137.000000       2.000000   0.010000    93.000000
# 75%    2015.000000       199.000000      15.000000   5.285000    97.000000
# max    2015.000000       484.000000     910.000000  10.660000    99.000000
#
#            Measles          BMI  Underfive_Deaths        Polio  Diphtheria   \
# count    182.000000  178.000000         182.000000  182.000000   182.000000
# mean    1482.104396   44.411236          28.851648   82.961538    84.357143
# ...

# %% [markdown]
# Outlier Treatment

# %%
df.isnull().sum()
# Out:
# Country                0
# Year                   0
# Status                 0
# Adult_Mortality        9
# Infant_Deaths          0
# Alcohol              167
# Hepatitis B            9
# Measles                0
# BMI                    4
# Underfive_Deaths       0
# Polio                  0
# Diphtheria             0
# HIV                    0
# GDP                   25
# Population            41
# Malnourished10_19      4
# Malnourished5_9        4
# Income_Index          13
# Schooling              9
# Life_Expectancy        9
# dtype: int64

# %%
df.Alcohol.isnull().sum()
# Out:
# 167

# %%
#The column 'Alcohol' can be dropped because more than 70% data is missing

# %%
df.drop(['Alcohol'], axis=1,inplace=True)

# %%
df.GDP.value_counts()
# Out:
# 584.259210      1
# 1431.244865     1
# 44292.884730    1
# 3821.893700     1
# 295.966488      1
#                ..
# 41176.881580    1
# 1361.113950     1
# 187.789910      1
# 9212.192824     1
# 118.693830      1
# Name: GDP, Length: 157, dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Adult_Mortality', 'Infant_Deaths',
#        'Hepatitis B', 'Measles ', 'BMI', 'Underfive_Deaths ', 'Polio',
#        'Diphtheria ', 'HIV', 'GDP', 'Population', 'Malnourished10_19',
#        'Malnourished5_9', 'Income_Index', 'Schooling', 'Life_Expectancy'],
#       dtype='object')

# %%
df.fillna(df.median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Country              0
# Year                 0
# Status               0
# Adult_Mortality      0
# Infant_Deaths        0
# Hepatitis B          0
# Measles              0
# BMI                  0
# Underfive_Deaths     0
# Polio                0
# Diphtheria           0
# HIV                  0
# GDP                  0
# Population           0
# Malnourished10_19    0
# Malnourished5_9      0
# Income_Index         0
# Schooling            0
# Life_Expectancy      0
# dtype: int64

# %%
df
# Out:
#          Country  Year      Status  Adult_Mortality  Infant_Deaths  \
# 0    Afghanistan  2015  Developing            263.0             62
# 1        Albania  2015  Developing             74.0              0
# 2        Algeria  2015  Developing             19.0             21
# 3         Angola  2015  Developing            335.0             66
# 4        Antigua  2015  Developing             13.0              0
# ..           ...   ...         ...              ...            ...
# 177    Venezuela  2015  Developing            157.0              9
# 178     Viet Nam  2015  Developing            127.0             28
# 179        Yemen  2015  Developing            224.0             37
# 180       Zambia  2015  Developing             33.0             27
# 181     Zimbabwe  2015  Developing            336.0             22
#
#      Hepatitis B  Measles    BMI  Underfive_Deaths   Polio  Diphtheria   HIV  \
# 0           65.0      1154  19.1                 83      6           65  0.1
# ...

# %% [markdown]
# Visualisation

# %% [markdown]
# - Univariate

# %%
df_num=df.select_dtypes(np.number)

# %%
df_num.drop(['Year'],inp)
# Out:
# (182, 17)

# %%
for i in df_num.columns:
    plt.plot(df[i])
    plt.title(i)
    plt.show()

# %%
#The line plots are not able to provide any insights

# %% [markdown]
# - Bivariate

# %%
#num vs cat

# %%
sns.barplot(x=df.Status, y='Life_Expectancy', data=df)
# Out:
# <Axes: xlabel='Status', ylabel='Life_Expectancy'>

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df.Status, y='Life_Expectancy', data=df)
plt.title(f'Distribution of Life Expectancy based on Status')
plt.show()

# %% [markdown]
# - The range of life expectancy of developed countries is larger than that of developed countries.
# - The median of developing countries is less than developed ones.

# %%
#num vs num

# %%
df_num.drop(['Year'],axis=1,inplace=True)

# %%
plt.figure(figsize=(25,25))
repeater=1
for i in df_num.columns:
    plt.subplot(4,4,repeater)
    sns.scatterplot(x=df_num.Life_Expectancy,y=df_num[i])
    plt.title(i)
    repeater+=1
plt.tight_layout()

# %% [markdown]
# - Adult mortality, malnourished5_9 have negetive correlation with life expectancy
# - Income index, schooling have have positive correlation with life expectancy

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df_num.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The features having strong correlation are:
# - Life Expectancy and Adult_Mortality
# - Life Expectancy and income index
# - Schooling and income index
# - Malnourished5_9 and malnourished10_19
# - Schooling and life expectancy
